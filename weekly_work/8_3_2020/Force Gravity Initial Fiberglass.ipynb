# %% [markdown]
# # Force Gravity of Different Assemblies
#
# ### Diagrams of simulation

# %% [markdown]
# ### Table of Contents
#
#  - [Aerogel](#Aerogel-Tile)
#  - [Assembly 1](#Assembly-1:-Middle,-normal-fiberglass)
#  - [Assembly 2](#Assembly-2:-Top-(above-surface),-normal-fiberglass)
#  - [Assembly 3](#Assembly-3:-Top-(below-surface),-normal-fiberglass)
#  - [Assembly 4](#Assembly-4:-Bottom-(above-surface),-normal-fiberglass)
#  - [Assembly 5](#Assembly-5:-Bottom-(below-surface),-normal-fiberglass)

# %% [markdown]
# ## Aerogel Tile
#
# ##### X-displacement
#
#  - Top view
#
#  ![Aerogel%20X1.png](attachment:Aerogel%20X1.png)
#
#  - Bottom view
#
#  ![Aerogel%20X2.png](attachment:Aerogel%20X2.png)
#
#  - Scale
#
#  ![Aerogel%20X3.png](attachment:Aerogel%20X3.png)
#
#
# ##### Y-displacement
#
#  - Top view
#
#  ![Aerogel%20Y1.png](attachment:Aerogel%20Y1.png)
#
#  - Bottom view
#  ![Aerogel%20Y2.png](attachment:Aerogel%20Y2.png)
#
#   - Scale
#   ![Aerogel%20Y3.png](attachment:Aerogel%20Y3.png)
#
#
#
# ## Assembly 1: Middle, normal fiberglass
#
# ##### X-displacement
#
#  - Top view
#
#  ![Assembly1%20X1.png](attachment:Assembly1%20X1.png)
#
#  - Side view
#
#  ![Assembly%201%20X2.png](attachment:Assembly%201%20X2.png)
#
#  - Scale
#
#  ![Assembly%201%20X3.png](attachment:Assembly%201%20X3.png)
#
#
#
# ##### Y-displacement
#
#  - Top view
#
#  ![Assembly%201%20Y1.png](attachment:Assembly%201%20Y1.png)
#
#  - Side view
#
#  ![Assembly%201%20Y2.png](attachment:Assembly%201%20Y2.png)
#
#  - Scale
#
#  ![Assembly%201%20Y3.png](attachment:Assembly%201%20Y3.png)
#
#
#
# ## Assembly 2: Top (above surface), normal fiberglass
#
# ##### X-displacement
#
#  - Bottom view
#
#  ![Assembly%202%20B.png](attachment:Assembly%202%20B.png)
#
#  - Scale
#
#  ![Assembly%202%20XS.png](attachment:Assembly%202%20XS.png)
#
#
# ##### Y-displacement
#
#  - Top view
#
#  ![Assembly%202%20Y1.png](attachment:Assembly%202%20Y1.png)
#
#  - Bottom view
#
#  ![Assembly%202%20Y2.png](attachment:Assembly%202%20Y2.png)
#
#  - Scale
#
#  ![Assembly%202%20Y3.png](attachment:Assembly%202%20Y3.png)

# %% [markdown]
# ## Assembly 3: Top (below surface), normal fiberglass
#
# ##### X-displacement
#
#  - Top view
#
#  ![Assembly%203%20XT.png](attachment:Assembly%203%20XT.png)
#
#  - Scale
#
#  ![Assembly%203%20XS.png](attachment:Assembly%203%20XS.png)
#
#
# ##### Y-displacement
#
#  - Side view
#
#  ![Assembly%203%20YSide.png](attachment:Assembly%203%20YSide.png)
#
#  - Scale
#
#  ![Assembly%203%20YScale.png](attachment:Assembly%203%20YScale.png)
#
#
#
#  ## Assembly 4: Bottom (above surface), normal fiberglass
#
#  ##### X-displacement
#
#   - Top
#
#   ![Assembly%204%20X1.png](attachment:Assembly%204%20X1.png)
#
#   - Bottom
#
#   ![Assembly%204%20X2.png](attachment:Assembly%204%20X2.png)
#
#   - Scale
#
#   ![Assembly%204%20X3.png](attachment:Assembly%204%20X3.png)
#
#
#  ##### Y-displacement
#
#  - Top
#
#  ![Assembly%204%20Y1.png](attachment:Assembly%204%20Y1.png)
#
#  - Bottom
#
#  ![Assembly%204%20Y2.png](attachment:Assembly%204%20Y2.png)
#
#  - Scale
#
#  ![Assembly%204%20Y3.png](attachment:Assembly%204%20Y3.png)
#
#
#
# ## Assembly 5: Bottom (below surface), normal fiberglass
#
# ##### X-displacement
#
#  - Top
#
#  ![Assembly%205%20XTop.png](attachment:Assembly%205%20XTop.png)
#
#  - Scale
#
#  ![Assembly%205%20X%20Scale.png](attachment:Assembly%205%20X%20Scale.png)
#
#
#  ##### Y-displacement:
#
#  - Side
#
#  ![Assembly%205%20Y%20Side.png](attachment:Assembly%205%20Y%20Side.png)
#
#  - Scale
#
#  ![Assembly%205%20Y%20Scale.png](attachment:Assembly%205%20Y%20Scale.png)
