# %% [markdown]
# # Force of Gravity on 2.15in Fiberglass
#
# ### Diagrams of simulation

# %% [markdown]
# ### Table of Contents
#
#  - [Assembly 6](#Assembly-6:-Middle,-2.15in-fiberglass)
#  - [Assembly 7](#Assembly-7:-Top-(above-surface),-2.15in-fiberglass)
#  - [Assembly 8](#Assembly-8:-Top-(below-surface),-2.15in-fiberglass)
#  - [Assembly 9](#Assembly-9:-Bottom-(above-surface),-2.15-in-fiberglass)
#  - [Assembly 10](#Assembly-10:-Bottom-(below-surface),-2.15in-fiberglass)

# %% [markdown]
# ## Assembly 6: Middle, 2.15in fiberglass
#
# ##### X-displacement
#
#  - Top
#
#  ![Assembly6%20X1.png](attachment:Assembly6%20X1.png)
#
#  - Bottom
#
#  ![6%20X2.png](attachment:6%20X2.png)
#
#  - Scale
#
#  ![6%20X3.png](attachment:6%20X3.png)
#
#
#  ##### Y-displacement
#
#  - Top
#
#  ![6%20Y1.png](attachment:6%20Y1.png)
#
#  - Bottom
#
#  ![6%20Y2.png](attachment:6%20Y2.png)
#
#  - Scale
#
#  ![6%20Y3.png](attachment:6%20Y3.png)
#
#
#
#  ## Assembly 7: Top (above surface), 2.15in fiberglass
#
#  ##### X-displacement
#
#  - Top
#
#  ![7%20X1.png](attachment:7%20X1.png)
#
#  - Bottom
#
#  ![7%20X%202.png](attachment:7%20X%202.png)
#
#  - Scale
#
#  ![7%20X3.png](attachment:7%20X3.png)
#
#
#  ##### Y-displacement
#
#  - Top
#
#  ![7Y1.png](attachment:7Y1.png)
#
#  - Bottom
#
#  ![7Y2.png](attachment:7Y2.png)
#
#  - Scale
#
#  ![7Y3.png](attachment:7Y3.png)
#
#
#
#  ## Assembly 8: Top (below surface), 2.15in fiberglass
#
#  ##### X-displacement
#
#  - Side
#
#  ![8%20Xside.png](attachment:8%20Xside.png)
#
#  - Scale
#
#  ![8%20X%20scale.png](attachment:8%20X%20scale.png)
#
#  ##### Y-displacement
#
#  - Side
#
#  ![8%20Yside.png](attachment:8%20Yside.png)
#
#  - Scale
#
#  ![8Yscale.png](attachment:8Yscale.png)
#
#
#
#  ## Assembly 9: Bottom (above surface), 2.15 in fiberglass
#
#  ##### X-displacement
#
#  - Top
#
#  ![9x1.png](attachment:9x1.png)
#
#  - Bottom
#
#  ![9x2.png](attachment:9x2.png)
#
#  - Scale
#
#  ![9x3.png](attachment:9x3.png)
#
#
# ##### Y-displacement
#
#  - Top
#
#  ![9y1.png](attachment:9y1.png)
#
#  - Bottom
#
#  ![9y2.png](attachment:9y2.png)
#
#  - Scale
#
#  ![9y3.png](attachment:9y3.png)
#
#
#
#  ## Assembly 10: Bottom (below surface), 2.15in fiberglass
#
#  ##### X-displacement
#
#  - Top
#
#  ![10xtop.png](attachment:10xtop.png)
#
#  - Side
#
#  ![10xside.png](attachment:10xside.png)
#
#  - Scale
#
#  ![10xscale.png](attachment:10xscale.png)
#
#
#  ##### Y-displacement
#
#  - Bottom
#
#  ![10ybottom.png](attachment:10ybottom.png)
#
#  - Scale
#
#  ![10yscale.png](attachment:10yscale.png)
