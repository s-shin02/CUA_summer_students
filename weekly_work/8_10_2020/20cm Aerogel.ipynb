# %%
import numpy as np
import matplotlib.pyplot as plt

pts = np.array([(2,4,6,8,10), (0.000001191,0.000002042,0.000002898,0.000003754,0.000004611),
                (0.000001543,0.000002442,0.000003425,0.00000442,0.000005415),
                (0.000001946,0.000002877,0.000003953,0.000005026,0.000006116),
                (0.00000229,0.00000321,0.000004389,0.000005565,0.000006742)])

                 
f = plt.figure(figsize=(11.69,8.27))

x_1 = pts[0,:]
y_1 = pts[1,:]
y_2 = pts[2,:]
y_3 = pts[3,:]
y_4 = pts[4,:]

plt.scatter(x_1,y_1, label = 'Assembly 15')
plt.scatter(x_1,y_2, label = 'Assembly 16')
plt.scatter(x_1,y_3, label = 'Assembly 17')
plt.scatter(x_1,y_4, label = 'Assembly 18')

m, b = np.polyfit(x_1, y_1, 1)
plt.plot(x_1, m*x_1 + b)
m, b = np.polyfit(x_1, y_2, 1)
plt.plot(x_1, m*x_1 + b)
m, b = np.polyfit(x_1, y_3, 1)
plt.plot(x_1, m*x_1 + b)
m, b = np.polyfit(x_1, y_4, 1)
plt.plot(x_1, m*x_1 + b)


plt.ylim(0, 0.000007)
plt.legend()
plt.title('X-Displacement', fontsize = 20)
plt.xlabel('Force (N)')
plt.ylabel('X-displacement (in)')
plt.show()

pts = np.array([(2,4,6,8,10), (0.00000229,0.000003651,0.000005013,0.000006374,0.000007734),
                (0.000003582,0.000005422,0.000007263,0.000009101,0.00001094),
                (0.000004912,0.000007159,0.000009404,0.00001165,0.0000139),
                (0.000006457,0.000009094,0.00001175,0.0000144,0.00001704)])


                 
f = plt.figure(figsize=(11.69,8.27))

x_1 = pts[0,:]
y_1 = pts[1,:]
y_2 = pts[2,:]
y_3 = pts[3,:]
y_4 = pts[4,:]

plt.scatter(x_1,y_1, label = 'Assembly 15')
plt.scatter(x_1,y_2, label = 'Assembly 16')
plt.scatter(x_1,y_3, label = 'Assembly 17')
plt.scatter(x_1,y_4, label = 'Assembly 18')

m, b = np.polyfit(x_1, y_1, 1)
plt.plot(x_1, m*x_1 + b)
m, b = np.polyfit(x_1, y_2, 1)
plt.plot(x_1, m*x_1 + b)
m, b = np.polyfit(x_1, y_3, 1)
plt.plot(x_1, m*x_1 + b)
m, b = np.polyfit(x_1, y_4, 1)
plt.plot(x_1, m*x_1 + b)


plt.ylim(0, 0.00002)
plt.legend()
plt.title('Y-Displacement', fontsize = 20)
plt.xlabel('Force (N)')
plt.ylabel('Y-displacement (in)')
plt.show()

# %% [markdown]
# As width increases, the displacement increases as well. Therefore, the ideal width would be the smallest of the tested options (3cm).
