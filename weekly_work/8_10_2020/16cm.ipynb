# %%
import numpy as np
import matplotlib.pyplot as plt

pts = np.array([(2,4,6,8,10), (0.000001327,0.000002379,0.000003427,0.000004478,0.000005531),
                (0.000001585,0.000002797,0.000004017,0.000005236,0.000006452),
                (0.000001772,0.000003103,0.000004438,0.00000577,0.0000071),
                (0.000001909,0.00000333,0.00000475,0.000006172,0.00000759)])

                 
f = plt.figure(figsize=(11.69,8.27))

x_1 = pts[0,:]
y_1 = pts[1,:]
y_2 = pts[2,:]
y_3 = pts[3,:]
y_4 = pts[4,:]

plt.scatter(x_1,y_1, label = 'Assembly 21')
plt.scatter(x_1,y_2, label = 'Assembly 29')
plt.scatter(x_1,y_3, label = 'Assembly 30')
plt.scatter(x_1,y_4, label = 'Assembly 31')

m, b = np.polyfit(x_1, y_1, 1)
plt.plot(x_1, m*x_1 + b)
m, b = np.polyfit(x_1, y_2, 1)
plt.plot(x_1, m*x_1 + b)
m, b = np.polyfit(x_1, y_3, 1)
plt.plot(x_1, m*x_1 + b)
m, b = np.polyfit(x_1, y_4, 1)
plt.plot(x_1, m*x_1 + b)


plt.ylim(0, 0.000008)
plt.legend()
plt.title('X-Displacement', fontsize = 20)
plt.xlabel('Force (N)')
plt.ylabel('X-displacement (in)')
plt.show()

pts = np.array([(2,4,6,8,10), (0.000003094,0.000005219,0.000007337,0.000009462,0.00001158),
                (0.000004439,0.0000072,0.000009959,0.00001272,0.00001548),
                (0.000005917,0.000009272,0.00001261,0.00001597,0.00001934),
                (0.000007448,0.00001132,0.00001519,0.00001906,0.00002294)])
                 
f = plt.figure(figsize=(11.69,8.27))

x_1 = pts[0,:]
y_1 = pts[1,:]
y_2 = pts[2,:]
y_3 = pts[3,:]
y_4 = pts[4,:]

plt.scatter(x_1,y_1, label = 'Assembly 21')
plt.scatter(x_1,y_2, label = 'Assembly 29')
plt.scatter(x_1,y_3, label = 'Assembly 30')
plt.scatter(x_1,y_4, label = 'Assembly 31')

m, b = np.polyfit(x_1, y_1, 1)
plt.plot(x_1, m*x_1 + b)
m, b = np.polyfit(x_1, y_2, 1)
plt.plot(x_1, m*x_1 + b)
m, b = np.polyfit(x_1, y_3, 1)
plt.plot(x_1, m*x_1 + b)
m, b = np.polyfit(x_1, y_4, 1)
plt.plot(x_1, m*x_1 + b)


plt.ylim(0, 0.000025)
plt.legend()
plt.title('Y-Displacement', fontsize = 20)
plt.xlabel('Force (N)')
plt.ylabel('Y-displacement (in)')
plt.show()

# %% [markdown]
# Smallest width had smallest displacement (3cm).
