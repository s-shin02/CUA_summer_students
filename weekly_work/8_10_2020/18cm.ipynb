# %%
import numpy as np
import matplotlib.pyplot as plt

pts = np.array([(2,4,6,8,10), (0.000001237,0.000002197,0.00000316,0.000004123,0.000005087),
                (0.000001564,0.000002653,0.000003742,0.000004831,0.000005921),
                (0.000001867,0.000003036,0.000004254,0.00000547,0.000006689),
                (0.000002117,0.000003314,0.000004625,0.000005935,0.000007247)])



                 
f = plt.figure(figsize=(11.69,8.27))

x_1 = pts[0,:]
y_1 = pts[1,:]
y_2 = pts[2,:]
y_3 = pts[3,:]
y_4 = pts[4,:]

plt.scatter(x_1,y_1, label = 'Assembly 22')
plt.scatter(x_1,y_2, label = 'Assembly 32')
plt.scatter(x_1,y_3, label = 'Assembly 33')
plt.scatter(x_1,y_4, label = 'Assembly 34')

m, b = np.polyfit(x_1, y_1, 1)
plt.plot(x_1, m*x_1 + b)
m, b = np.polyfit(x_1, y_2, 1)
plt.plot(x_1, m*x_1 + b)
m, b = np.polyfit(x_1, y_3, 1)
plt.plot(x_1, m*x_1 + b)
m, b = np.polyfit(x_1, y_4, 1)
plt.plot(x_1, m*x_1 + b)


plt.ylim(0, 0.0000075)
plt.legend()
plt.title('X-Displacement', fontsize = 20)
plt.xlabel('Force (N)')
plt.ylabel('X-displacement (in)')
plt.show()

pts = np.array([(2,4,6,8,10), (0.000002707,0.000004422,0.000006138,0.000007858,0.000009572),
                (0.000003941,0.000006172,0.000008402,0.00001063,0.00001286),
                (0.000005363,0.000008095,0.00001083,0.00001356,0.00001629),
                (0.000006919,0.00001012,0.00001332,0.00001652,0.00001972)])
                


                 
f = plt.figure(figsize=(11.69,8.27))

x_1 = pts[0,:]
y_1 = pts[1,:]
y_2 = pts[2,:]
y_3 = pts[3,:]
y_4 = pts[4,:]

plt.scatter(x_1,y_1, label = 'Assembly 22')
plt.scatter(x_1,y_2, label = 'Assembly 32')
plt.scatter(x_1,y_3, label = 'Assembly 33')
plt.scatter(x_1,y_4, label = 'Assembly 34')

m, b = np.polyfit(x_1, y_1, 1)
plt.plot(x_1, m*x_1 + b)
m, b = np.polyfit(x_1, y_2, 1)
plt.plot(x_1, m*x_1 + b)
m, b = np.polyfit(x_1, y_3, 1)
plt.plot(x_1, m*x_1 + b)
m, b = np.polyfit(x_1, y_4, 1)
plt.plot(x_1, m*x_1 + b)


plt.ylim(0, 0.00002)
plt.legend()
plt.title('Y-Displacement', fontsize = 20)
plt.xlabel('Force (N)')
plt.ylabel('Y-displacement (in)')
plt.show()

# %% [markdown]
# Again, the one with the smallest width had the smallest displacement in both displacements. (3cm)
