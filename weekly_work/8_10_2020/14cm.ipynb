# %%
import numpy as np
import matplotlib.pyplot as plt

pts = np.array([(2,4,6,8,10), (0.000001476,0.000002728,0.000003979,0.00000523,0.000006481),
                (0.000001705,0.00000312,0.000004536,0.000005951,0.000007367),
                (0.000001851,0.000003374,0.000004897,0.00000642,0.000007943),
                (0.000001931,0.000003522,0.000005112,0.000006704,0.000008294)])


                 
f = plt.figure(figsize=(11.69,8.27))

x_1 = pts[0,:]
y_1 = pts[1,:]
y_2 = pts[2,:]
y_3 = pts[3,:]
y_4 = pts[4,:]

plt.scatter(x_1,y_1, label = 'Assembly 20')
plt.scatter(x_1,y_2, label = 'Assembly 26')
plt.scatter(x_1,y_3, label = 'Assembly 27')
plt.scatter(x_1,y_4, label = 'Assembly 28')

m, b = np.polyfit(x_1, y_1, 1)
plt.plot(x_1, m*x_1 + b)
m, b = np.polyfit(x_1, y_2, 1)
plt.plot(x_1, m*x_1 + b)
m, b = np.polyfit(x_1, y_3, 1)
plt.plot(x_1, m*x_1 + b)
m, b = np.polyfit(x_1, y_4, 1)
plt.plot(x_1, m*x_1 + b)


plt.ylim(0.000001, 0.0000085)
plt.legend()
plt.title('X-Displacement', fontsize = 20)
plt.xlabel('Force (N)')
plt.ylabel('X-displacement (in)')
plt.show()

pts = np.array([(2,4,6,8,10), (0.00000367,0.000006396,0.00000912,0.00001184,0.00001456),
                (0.000005135,0.000008636,0.00001214,0.00001564,0.00001914),
                (0.00000663,0.0000108,0.00001497,0.00001914,0.00002331),
                (0.000008052,0.00001276,0.00001747,0.00002217,0.00002688)])

                 
f = plt.figure(figsize=(11.69,8.27))

x_1 = pts[0,:]
y_1 = pts[1,:]
y_2 = pts[2,:]
y_3 = pts[3,:]
y_4 = pts[4,:]

plt.scatter(x_1,y_1, label = 'Assembly 20')
plt.scatter(x_1,y_2, label = 'Assembly 26')
plt.scatter(x_1,y_3, label = 'Assembly 27')
plt.scatter(x_1,y_4, label = 'Assembly 28')

m, b = np.polyfit(x_1, y_1, 1)
plt.plot(x_1, m*x_1 + b)
m, b = np.polyfit(x_1, y_2, 1)
plt.plot(x_1, m*x_1 + b)
m, b = np.polyfit(x_1, y_3, 1)
plt.plot(x_1, m*x_1 + b)
m, b = np.polyfit(x_1, y_4, 1)
plt.plot(x_1, m*x_1 + b)


plt.ylim(0, 0.00003)
plt.legend()
plt.title('Y-Displacement', fontsize = 20)
plt.xlabel('Force (N)')
plt.ylabel('Y-displacement (in)')
plt.show()

# %% [markdown]
# 3cm had the smallest displacement.
