# %%
import numpy as np
import matplotlib.pyplot as plt

pts = np.array([(2,4,6,8,10), (0.00000134,0.000002569,0.000003798,0.000005028,0.000006257),
                (0.000001476,0.000002728,0.000003979,0.00000523,0.000006481),
                (0.000001327,0.000002379,0.000003427,0.000004478,0.000005531),
                (0.000001237,0.000002197,0.00000316,0.000004123,0.000005087),
                (7.631E-07,0.000001508,0.000002253,0.000002998,0.000003743)])


                 
f = plt.figure(figsize=(11.69,8.27))

x_1 = pts[0,:]
y_1 = pts[1,:]
y_2 = pts[2,:]
y_3 = pts[3,:]
y_4 = pts[4,:]
y_5 = pts[5,:]

plt.scatter(x_1,y_1, label = 'Assembly 19')
plt.scatter(x_1,y_2, label = 'Assembly 20')
plt.scatter(x_1,y_3, label = 'Assembly 21')
plt.scatter(x_1,y_4, label = 'Assembly 22')
plt.scatter(x_1,y_5, label = 'Assembly 5')

m, b = np.polyfit(x_1, y_1, 1)
plt.plot(x_1, m*x_1 + b)
m, b = np.polyfit(x_1, y_2, 1)
plt.plot(x_1, m*x_1 + b)
m, b = np.polyfit(x_1, y_3, 1)
plt.plot(x_1, m*x_1 + b)
m, b = np.polyfit(x_1, y_4, 1)
plt.plot(x_1, m*x_1 + b)
m, b = np.polyfit(x_1, y_5, 1)
plt.plot(x_1, m*x_1 + b)

plt.ylim(0, 0.0000085)
plt.legend()
plt.title('X-Displacement', fontsize = 20)
plt.xlabel('Force (N)')
plt.ylabel('X-displacement (in)')
plt.show()

pts = np.array([(2,4,6,8,10), (0.00000367,0.000006396,0.00000912,0.00001184,0.00001456),
                (0.000005135,0.000008636,0.00001214,0.00001564,0.00001914),
                (0.00000663,0.0000108,0.00001497,0.00001914,0.00002331),
                (0.000008052,0.00001276,0.00001747,0.00002217,0.00002688),
                (0.000001828,0.00000356,0.000005291,0.000007023,0.000008755)])

                 
f = plt.figure(figsize=(11.69,8.27))

x_1 = pts[0,:]
y_1 = pts[1,:]
y_2 = pts[2,:]
y_3 = pts[3,:]
y_4 = pts[4,:]
y_5 = pts[5,:]

plt.scatter(x_1,y_1, label = 'Assembly 19')
plt.scatter(x_1,y_2, label = 'Assembly 20')
plt.scatter(x_1,y_3, label = 'Assembly 21')
plt.scatter(x_1,y_4, label = 'Assembly 22')
plt.scatter(x_1,y_5, label = 'Assembly 5')

m, b = np.polyfit(x_1, y_1, 1)
plt.plot(x_1, m*x_1 + b)
m, b = np.polyfit(x_1, y_2, 1)
plt.plot(x_1, m*x_1 + b)
m, b = np.polyfit(x_1, y_3, 1)
plt.plot(x_1, m*x_1 + b)
m, b = np.polyfit(x_1, y_4, 1)
plt.plot(x_1, m*x_1 + b)
m, b = np.polyfit(x_1, y_5, 1)
plt.plot(x_1, m*x_1 + b)


plt.ylim(0, 0.00003)
plt.legend()
plt.title('Y-Displacement', fontsize = 20)
plt.xlabel('Force (N)')
plt.ylabel('Y-displacement (in)')
plt.show()

# %% [markdown]
# As per the trend, the smallest length and width had the smallest displacement. In this case, it is the og 10cmx10cmx1cm Assembly 5.
