# %% [markdown]
# ## X-displacements

# %%
import numpy as np
import matplotlib.pyplot as plt

pts = np.array([(0.007,0.013,0.019,0.026,0.033,0.039,0.045,0.052,0.059,0.065), (0.000005276,0.000005275,0.000005275,0.000005275,0.000005275,0.000005275,0.000005275,0.000005275,0.000005274,0.000005274),
               (0.000003669,0.000003669,0.000003669,0.000003669,0.000003669,0.000003669,0.000003669,0.000003669,0.000003669,0.000003669),
            (0.000005821,0.000005821,0.000005821,0.000005819,0.00000582,0.00000582,0.000005819,0.000005821,0.00000582,0.000005818),
               (0.006,0.0012,0.018,0.024,0.030,0.037,0.043,0.049,0.055,0.061), (0.000005972,0.000005972,0.000005972,0.000005972,0.000005972,0.000005972,0.000005972,0.000005972,0.000005971,0.000005971),
                (0.000003679,0.000003679,0.000003679,0.000003679,0.000003679,0.000003679,0.000003679,0.000003679,0.000003679,0.000003679),
                (0.000005276,0.000005275,0.000005275,0.000005275,0.000005275,0.000005275,0.000005275,0.000005275,0.000005274,0.000005274)])

f = plt.figure(figsize=(11.69,8.27))

x_1 = pts[0,:]
y_1 = pts[1,:]
y_2 = pts[2,:]
y_3 = pts[3,:]
x_2 = pts[4,:]
y_4 = pts[5,:]
y_5 = pts[6,:]
y_6 = pts[7,:]

plt.scatter(x_1,y_1, label = 'Assembly 1')
plt.scatter(x_1,y_2, label = 'Assembly 5')
plt.scatter(x_1,y_3, label = 'Assembly 6')
plt.scatter(x_2,y_4, label = 'Assembly 1 (Old)')
plt.scatter(x_2,y_5, label = 'Assembly 5 (Old)')
plt.scatter(x_2,y_6, label = 'Assembly 6 (Old)')

m, b = np.polyfit(x_1, y_1, 1)
plt.plot(x_1, m*x_1 + b)
m, b = np.polyfit(x_1, y_2, 1)
plt.plot(x_1, m*x_1 + b)
m, b = np.polyfit(x_1, y_3, 1)
plt.plot(x_1, m*x_1 + b)
m, b = np.polyfit(x_2, y_4, 1)
plt.plot(x_2, m*x_2 + b)
m, b = np.polyfit(x_2, y_5, 1)
plt.plot(x_2, m*x_2 + b)
m, b = np.polyfit(x_2, y_6, 1)
plt.plot(x_2, m*x_2 + b)

plt.ylim(0.000003, 0.00001)
plt.legend()
plt.title('X-Displacement', fontsize = 20)
plt.xlabel(r'$\frac{lbs}{in^3}$', fontsize = 15)
plt.ylabel('X-displacement (in)')
plt.show()

# %% [markdown]
# ## Y-displacements

# %%
pts = np.array([(0.007,0.013,0.019,0.026,0.033,0.039,0.045,0.052,0.059,0.065), (0.000009152,0.000009152,0.000009152,0.000009155,0.000009152,0.000009152,0.000009152,0.000009152,0.000009152,0.000009152),
               (0.000008583,0.000008581,0.000008581,0.000008581,0.000008581,0.000008581,0.000008581,0.000008582,0.000008582,0.000008581),
            (0.00002484,0.00002484,0.00002484,0.00002484,0.00002484,0.00002484,0.00002484,0.00002484,0.00002484,0.00002484),
               (0.006,0.0012,0.018,0.024,0.030,0.037,0.043,0.049,0.055,0.061), (0.000009114,0.000009114,0.000009114,0.000009114,0.000009114,0.000009114,0.000009115,0.000009115,0.000009114,0.000009114),
                (0.000008576,0.000008578,0.000008577,0.000008577,0.000008577,0.000008577,0.000008576,0.000008576,0.000008577,0.000008576),
                (0.00002472,0.00002472,0.00002472,0.00002472,0.00002472,0.00002472,0.00002473,0.00002472,0.00002473,0.00002472)])

f = plt.figure(figsize=(11.69,8.27))

x_1 = pts[0,:]
y_1 = pts[1,:]
y_2 = pts[2,:]
y_3 = pts[3,:]
x_2 = pts[4,:]
y_4 = pts[5,:]
y_5 = pts[6,:]
y_6 = pts[7,:]

plt.scatter(x_1,y_1, label = 'Assembly 1')
plt.scatter(x_1,y_2, label = 'Assembly 5')
plt.scatter(x_1,y_3, label = 'Assembly 6')
plt.scatter(x_2,y_4, label = 'Assembly 1 (Old)')
plt.scatter(x_2,y_5, label = 'Assembly 5 (Old)')
plt.scatter(x_2,y_6, label = 'Assembly 6 (Old)')

m, b = np.polyfit(x_1, y_1, 1)
plt.plot(x_1, m*x_1 + b)
m, b = np.polyfit(x_1, y_2, 1)
plt.plot(x_1, m*x_1 + b)
m, b = np.polyfit(x_1, y_3, 1)
plt.plot(x_1, m*x_1 + b)
m, b = np.polyfit(x_2, y_4, 1)
plt.plot(x_2, m*x_2 + b)
m, b = np.polyfit(x_2, y_5, 1)
plt.plot(x_2, m*x_2 + b)
m, b = np.polyfit(x_2, y_6, 1)
plt.plot(x_2, m*x_2 + b)

plt.ylim(0.0000085, 0.0000094)
plt.legend()
plt.title('Y-Displacement', fontsize = 20)
plt.xlabel(r'$\frac{lbs}{in^3}$', fontsize = 15)
plt.ylabel('Y-displacement (in)')
plt.show()

# %% [markdown]
# Conclusion:
#
# Assembly 5 showed the best outcome for different fiberglass density. Although the density itself didn't affect the displacement, there were differences in the displacement between the assemblies.
#
# Both the old and new properties should be tested.
# X-dis: the new fiberglass properties showed smaller displacement.
# Y-dis: old fiberglass properties showed smaller displacement.
#
# Since the scale is really small, all three assemblies can work as they will not break the aerogel.
# - Assembly 5's position and fiberglass will be tested for time sake with normal fiberglass density.
